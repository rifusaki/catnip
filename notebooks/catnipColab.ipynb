# %% [markdown]
# # catnip colab — stage 1 training
#
# Train YOLO26 body/head/face detector using pre-sliced data from GCS.
#
# **Before colab:** run locally on dev machine then upload:
# ```bash
# python scripts/unify/stage1.py --slice --slice-workers 4
# gsutil -m rsync -r /Volumes/rifuSSD/catnip-data/training/stage1_sliced/ gs://catnip-data/training/stage1_sliced/
# gsutil cp /Volumes/rifuSSD/catnip-data/models/yolo26n.pt gs://catnip-data/models/yolo26n.pt
# ```
#
# **Runtime:** GPU → T4. Max 12h session, 90min idle timeout.

# %% [markdown]
# ### 1. mount gcs + install deps

# %%
REPO_URL = "https://github.com/rifusaki/catnip.git"
BUCKET = "catnip-data"
MOUNT_POINT = "/content/catnip-data"
REPO_DIR = "/content/catnip"
BRANCH = "refactor/reID"

# clone
# !git clone -b {BRANCH} {REPO_URL} {REPO_DIR}
# %cd {REPO_DIR}

from google.colab import auth
auth.authenticate_user()

# install gcsfuse
# !echo "deb http://packages.cloud.google.com/apt gcsfuse-bionic main" > /etc/apt/sources.list.d/gcsfuse.list
# !curl -s https://packages.cloud.google.com/apt/doc/apt-key.gpg | apt-key add -
# !apt -qq update && apt -qq install gcsfuse 2>&1 | tail -1

# mount bucket
import subprocess, sys, os
# !mkdir -p {MOUNT_POINT}
result = subprocess.run(["gcsfuse", "--implicit-dirs", BUCKET, MOUNT_POINT],
                        capture_output=True, text=True)
if result.returncode != 0:
    print(f"gcsfuse ERROR: {result.stderr}")
    sys.exit(1)

# env var for src/config.py (uses ${oc.env:CATNIP_DATA})
# %env CATNIP_DATA={MOUNT_POINT}
os.environ["CATNIP_DATA"] = MOUNT_POINT

# deps (matches pixi.toml)
# %pip install --quiet \
    "numpy<2" \
    "ultralytics>=8.4,<9" \
    "pydantic>=2.11,<3"        "pydantic-settings>=2.11,<3" \
    "omegaconf>=2.3,<3"        "sahi>=0.11.36,<0.13" \
    "opencv-python>=4.10,<5"   "python-dotenv>=1,<2" \
    "scikit-learn>=1.7,<2"     "manga109api>=0.3.1,<0.4"

if REPO_DIR not in sys.path:
    sys.path.insert(0, REPO_DIR)

# quick sanity
# !ls {MOUNT_POINT}/training/stage1_sliced/dataset.yaml
# !nvidia-smi -L || true
print(f"CATNIP_DATA={os.environ.get('CATNIP_DATA', 'UNSET')}")

# %% [markdown]
# ### 2. train stage 1
#
# Uses the pre-sliced dataset on GCS. Overrides `device` to `cuda` (config defaults to `mps` for local mac).
#
# Defaults from `config/pipeline.yaml`: yolo26n, imgsz=640, batch=8, epochs=300, workers=4.

# %%
import subprocess, sys, os

print(f"CATNIP_DATA = {os.environ.get('CATNIP_DATA', 'UNSET')}")
print(f"device = {sys.executable}")

# capture=False so YOLO progress bars show inline
result = subprocess.run(
    [sys.executable, "-u", "scripts/train/stage1.py",
     "--override", "training.stage1.device=cuda",
     "--override", "training.stage1.workers=4",
     "--verbose"],
    capture_output=False,
)
if result.returncode != 0:
    print(f"\nTraining failed with exit code {result.returncode}.")
    sys.exit(result.returncode)

# %% [markdown]
# ### 3. verify

# %%
import os, sys
os.environ.setdefault("CATNIP_DATA", "/content/catnip-data")
sys.path.insert(0, "/content/catnip")

from pathlib import Path
from src.config import load_settings

settings = load_settings("config/pipeline.yaml")

best_model = settings.paths.model_dir / "yolo26_stage1_body_head_face.pt"
runs_dir = settings.paths.runs_dir / "detect" / "stage1"

print(f"best model: {best_model}  {'OK' if best_model.exists() else 'MISSING'}")
print(f"runs dir:   {runs_dir}")

results_csv = runs_dir / "results.csv"
if results_csv.exists():
    print(f"\nlast 5 epochs:")
    # !tail -5 {results_csv}

results_png = runs_dir / "results.png"
if results_png.exists():
    print(f"curves: {results_png}")

# %% [markdown]
# ### after training — pull back to local
#
# ```bash
# gsutil cp gs://catnip-data/models/yolo26_stage1_body_head_face.pt \
#     /Volumes/rifuSSD/catnip-data/models/
# gsutil cp -r gs://catnip-data/runs/detect/stage1/ \
#     /Volumes/rifuSSD/catnip-data/runs/detect/
# ```

# %% [markdown]
# # catnip colab — stage 1 training

# %% [markdown]
# ### 0. dataset preparation (create tarball)

# %%
from google.colab import auth
auth.authenticate_user()

BUCKET = "catnip-data"
SOURCE_GCS_DIR = f"gs://{BUCKET}/training/stage1_sliced/"
ARCHIVE_DESTINATION = f"gs://{BUCKET}/compressed/stage1_sliced.tar"

# 1. Rapidly download the 13k individual files to Colab's temporary local storage
# gcloud storage is highly parallelized and much faster than FUSE for this
print("Pulling 13k files from GCS to Colab...")
# !mkdir /content/temp_dataset
# !gcloud storage cp -R {SOURCE_GCS_DIR} /content/temp_dataset/

# 2. Compress the downloaded folder into a single .tar archive on Colab
print("Compressing files into a single archive...")
# !tar -cf /content/stage1_sliced.tar -C /content/temp_dataset/ .

# 3. Upload the new archive back to your GCS bucket
print("Uploading archive back to bucket...")
# !gcloud storage cp /content/stage1_sliced.tar {ARCHIVE_DESTINATION}

# 4. Clean up the Colab instance's local disk
print("Cleaning up...")
# !rm -rf /content/temp_dataset/ /content/stage1_sliced.tar

print(f"Done! Your archive is waiting for you at {ARCHIVE_DESTINATION}")

# %% [markdown]
# ### 1. mount gcs + install deps

# %%
from google.colab import auth
auth.authenticate_user()

REPO_URL = "https://github.com/rifusaki/catnip.git"
BUCKET = "catnip-data"
MOUNT_POINT = "/content/catnip-data"
REPO_DIR = "/content/catnip"
BRANCH = "refactor/reID"

# clone
# !git clone -b {BRANCH} {REPO_URL} {REPO_DIR}
# %cd {REPO_DIR}

import os, sys

# install gcsfuse
# !echo "deb http://packages.cloud.google.com/apt gcsfuse-bionic main" > /etc/apt/sources.list.d/gcsfuse.list
# !curl -s https://packages.cloud.google.com/apt/doc/apt-key.gpg | apt-key add -
# !apt -qq update && apt -qq install gcsfuse 2>&1 | tail -1

# Define local paths
ARCHIVE_GCS_PATH = f"gs://{BUCKET}/compressed/stage1_sliced.tar"
LOCAL_DATA_DIR = "/content/catnip-data-local/training"

# !mkdir -p {LOCAL_DATA_DIR}

# Download the single archive using high-speed parallel download
print("Downloading dataset archive...")
# !gcloud storage cp {ARCHIVE_GCS_PATH} /content/stage1_sliced.tar

# Extract locally to Colab's fast SSD
print("Extracting dataset...")
# !tar -xf /content/stage1_sliced.tar -C {LOCAL_DATA_DIR}

# Clean up the archive to save disk space
# !rm /content/stage1_sliced.tar

# Point your environment variables to the fast local directory
# %env CATNIP_DATA={LOCAL_DATA_DIR}
os.environ["CATNIP_DATA"] = LOCAL_DATA_DIR

print("Data loaded to local NVMe!")

# deps (matches pixi.toml; do NOT pin numpy<2 — Colab has pre-installed
# packages compiled against numpy 2.x, downgrade causes ABI conflicts)
# %pip install --quiet \
    "ultralytics>=8.4,<9" \
    "pydantic>=2.11,<3"        "pydantic-settings>=2.11,<3" \
    "omegaconf>=2.3,<3"        "sahi>=0.11.36,<0.13" \
    "opencv-python>=4.10,<5"   "python-dotenv>=1,<2" \
    "scikit-learn>=1.7,<2"     "manga109api>=0.3.1,<0.4"

if REPO_DIR not in sys.path:
    sys.path.insert(0, REPO_DIR)

# quick sanity
# !ls {MOUNT_POINT}/training/stage1_sliced/dataset.yaml
# !nvidia-smi -L || true
print(f"CATNIP_DATA={os.environ.get('CATNIP_DATA', 'UNSET')}")

# %% [markdown]
# ### 2. train stage 1
#
# Uses the pre-sliced dataset on GCS. Overrides `device` to `cuda` (config defaults to `mps` for local mac).
#
# Defaults from `config/pipeline.yaml`: yolo26n, imgsz=640, batch=8, epochs=300, workers=4. Overridden for Colab nano test: batch=128, epochs=30.

# %%
import sys, os
from pathlib import Path

REPO_DIR = "/content/catnip"
sys.path.insert(0, REPO_DIR)
os.chdir(REPO_DIR)
os.environ.setdefault("CATNIP_DATA", "/content/catnip-data-local")

print(f"CATNIP_DATA = {os.environ.get('CATNIP_DATA', 'UNSET')}")
print(f"python = {sys.executable}")

# Patch dataset.yaml — the sliced YAML uses path: .
# but ultralytics 8.4.x resolves *relative to CWD* not the YAML dir.
import yaml as _yaml
_yaml_path = "/content/catnip-data-local/training/stage1_sliced/dataset.yaml"
_data = _yaml.safe_load(Path(_yaml_path).read_text())
_data["path"] = str(Path(_yaml_path).parent.resolve())
Path(_yaml_path).write_text(_yaml.dump(_data, default_flow_style=False))
print(f"dataset.yaml path → {_data['path']}")

# Run training in-process — subprocess stdout/stderr gets lost on Colab
# (capture_output=False writes to raw FDs that bypass cell output).
sys.argv = [
    "stage1.py",
    "--override", "training.stage1.device=cuda",
    "--override", "training.stage1.workers=4",
    "--override", "training.stage1.batch=64",
    "--override", "training.stage1.epochs=30",
    "--verbose",
]

from scripts.train import stage1
try:
    stage1.main()
except SystemExit as e:
    print(f"\nTraining failed with exit code {e.code}.")
    raise

# %% [markdown]
# ### 3. verify

# %%
import os, sys
os.environ.setdefault("CATNIP_DATA", "/content/catnip-data-local")
sys.path.insert(0, "/content/catnip")

from pathlib import Path
from src.config import load_settings

settings = load_settings("config/pipeline.yaml")

best_model = settings.paths.model_dir / "yolo26_stage1_body_head_face.pt"
runs_dir = settings.paths.runs_dir / "detect" / "stage1"

print(f"best model: {best_model}  {'OK' if best_model.exists() else 'MISSING'}")
print(f"runs dir:   {runs_dir}")

results_csv = runs_dir / "results.csv"
if results_csv.exists():
    print(f"\nlast 5 epochs:")
    # !tail -5 {results_csv}

results_png = runs_dir / "results.png"
if results_png.exists():
    print(f"curves: {results_png}")

# %% [markdown]
# ### 4. upload results to GCS

# %%
print("Uploading model and runs to GCS...")
# !gcloud storage cp /content/catnip-data-local/models/yolo26_stage1_body_head_face.pt gs://catnip-data/models/
# !gcloud storage cp -r /content/catnip-data-local/runs/detect/stage1/ gs://catnip-data/runs/detect/
print("Done!")
